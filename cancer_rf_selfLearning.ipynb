# %% [markdown]
# # The data of details of cell nuclei taken from breast mass are given in cancer.csv  and predict whether or not a patient has breast cancer using the Ensembling Techniques. Perform necessary exploratory data analysis before building the model and evaluate the model based on performance metrics other than model accuracy.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("cancer.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# ### We dont need ID and Unnamed: 32 columns as those are irrelevent columns for EDA and Model(Random Forest) building.

# %%
df.drop(columns=['Unnamed: 32','id'],inplace=True)

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# ### Our dataset is all cleared i.e. It has not null values or missing values. So we can perform Exploratory Data Analysis.

# %%
sns.countplot(df['diagnosis'])
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %% [markdown]
# ### Above target variable shows a person is having cancer or not. Malignant(M) and Benign(B) gives cancer and not cancer information respectively. More than 350 people are not having cancer.

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df['diagnosis'].value_counts().plot(kind='pie',autopct='%.f%%')
# Out:
# <AxesSubplot:ylabel='diagnosis'>

# %% [markdown]
# ### 63% people are safe(not cancer) and 37% people are cancerous.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labenc=LabelEncoder()
df['diagnosis']=labenc.fit_transform(df['diagnosis'])

# %%
df['diagnosis'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# 'M':1,'B':0

# %%
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
plt.figure(figsize=(17,17))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
plt.show()

# %% [markdown]
# ### radius_worst is highly corelated to radius_mean, perimeter_mean, area_mean.
# ### perimeter_worst is highly corelated to radius_mean, perimeter_mean, area_mean.
# ### area_worst is highly corelated to radius_mean, perimeter_mean, area_mean.
# ### perimeter_worst is highly corelated to radius_worst, texture_mean, area_worst.
# ### radius_mean is highly corelated to perimeter_mean, area_mean.
# ### concave points_worst is highly corelated to concave points_mean.

# %%
sns.scatterplot(x=df['radius_worst'],y=df['radius_mean'])
# Out:
# <AxesSubplot:xlabel='radius_worst', ylabel='radius_mean'>

# %% [markdown]
# ### radius_worst and radius_mean is linearly corelated to each other.

# %%
sns.scatterplot(x=df['perimeter_worst'],y=df['radius_mean'])
# Out:
# <AxesSubplot:xlabel='perimeter_worst', ylabel='radius_mean'>

# %% [markdown]
# ### perimeter_worst and radius_mean is linearly corelated to each other.

# %%
sns.lineplot(x=df['diagnosis'],y=df['concave points_mean'])
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='concave points_mean'>

# %%
sns.lineplot(x=df['diagnosis'],y=df['concave points_worst'])
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='concave points_worst'>

# %% [markdown]
# ### Both concave points_worst and concave points_mean are linearly shows relation with target variable diagnosis.

# %%
sns.barplot(x='diagnosis',y='area_worst',data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='area_worst'>

# %% [markdown]
# ### Diagnosis is showing high records i.e. around 1400, of malignant with respect to area_worst.

# %%
sns.barplot(x='diagnosis',y='perimeter_worst',data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='perimeter_worst'>

# %% [markdown]
# ### Diagnosis is showing high records i.e. around 140, of malignant with respect to perimeter_worst.

# %%
sns.barplot(x='diagnosis',y='radius_worst',data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='radius_worst'>

# %% [markdown]
# ### Diagnosis is showing high records i.e. above 20, of malignant with respect to radius_worst.

# %%
X=df.drop(columns=['diagnosis'])
y=df.diagnosis

# %%
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy')
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_train_pred=classifier.predict(X_train)
y_test_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
def metric(y_act,y_pred):
    print(classification_report(y_act,y_pred))
    print(accuracy_score(y_act,y_pred))
    print(confusion_matrix(y_act,y_pred))

# %%
print('Train data')
print(metric(y_train,y_train_pred))
print('Test data')
print(metric(y_test,y_test_pred))
# Out:
# Train data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       267
#            1       0.99      0.99      0.99       159
#
#     accuracy                           1.00       426
#    macro avg       0.99      0.99      0.99       426
# weighted avg       1.00      1.00      1.00       426
#
# 0.9953051643192489
# [[266   1]
#  [  1 158]]
# None
# Test data
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        90
#            1       0.93      0.96      0.94        53
#
#     accuracy                           0.96       143
#    macro avg       0.95      0.96      0.96       143
# weighted avg       0.96      0.96      0.96       143
#
# 0.958041958041958
# [[86  4]
#  [ 2 51]]
# None

# %% [markdown]
# ### Our Train data and Test data are giving 99% and 95% accuracy score respectively.
# ### False Negative and False Positive are also less from confusion matrix, so its best model to predict if a person is having cancer or not.

# %%
df.iloc[3,1:] # we are assuming this data to check if our model is working properly or not.(dont consider diagnosis column).
# Out:
# radius_mean                 11.420000
# texture_mean                20.380000
# perimeter_mean              77.580000
# area_mean                  386.100000
# smoothness_mean              0.142500
# compactness_mean             0.283900
# concavity_mean               0.241400
# concave points_mean          0.105200
# symmetry_mean                0.259700
# fractal_dimension_mean       0.097440
# radius_se                    0.495600
# texture_se                   1.156000
# perimeter_se                 3.445000
# area_se                     27.230000
# smoothness_se                0.009110
# compactness_se               0.074580
# concavity_se                 0.056610
# concave points_se            0.018670
# symmetry_se                  0.059630
# fractal_dimension_se         0.009208
# radius_worst                14.910000
# texture_worst               26.500000
# perimeter_worst             98.870000
# area_worst                 567.700000
# smoothness_worst             0.209800
# ...

# %%
classifier.predict([[11.42,20.38,77.58,386.1,0.14,0.28,0.24,0.10,0.25,0.09,0.49,1.15,3.44,27.23,0,0.07,0.05,0.01,0.05,0,14.9,26.5,98.87,567.7,0.2,0.86,0.68,0.25,0.66,0.17]])
# Out:
# array([1])

# %% [markdown]
# ## Our Model is working properly !!!
